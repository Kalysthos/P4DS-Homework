# %%
from scatter import scatter, plotcorr
from plots import trend, xsml, trend_years
import pandas as pd 
data = pd.read_pickle("data.pickle")
corr = pd.read_pickle("corrGDP2017.pickle")
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
corr
# Out:
#                                                                R2  \
# Index                                              Year
# Access to electricity (% of population)            1990  0.694383
#                                                    1991  0.693759
#                                                    1992  0.692375
#                                                    1993  0.691458
#                                                    1994  0.691498
#                                                    1995  0.690936
#                                                    1996  0.689077
#                                                    1997  0.690244
#                                                    1998  0.679492
#                                                    1999  0.679447
#                                                    2000  0.672002
#                                                    2001  0.686528
# ...

# %%
scatter(data, ['GDP per capita (current US$)', 'Economic freedom'], [2017, 2016])

# %%
xsml(data,  ['GDP per capita (current US$)', 'Economic freedom'], [2017, 2016], 4)

# %%
trend_years(data, 'Economic freedom', 'World', [2000, 2017])

# %%
scatter(data, ['GDP per capita (current US$)', 
               'Domestic general government health expenditure per capita (current US$)'], [2017, 2015])

# %%
xsml(data,  ['GDP per capita (current US$)', 
             'Domestic general government health expenditure per capita (current US$)'], [2017, 2015], 4)

# %%
trend_years(data, ['GDP per capita (current US$)', 
                   'Domestic general government health expenditure per capita (current US$)'], 
            'World', [2000, 2017])

# %%
trend(data, 'Domestic general government health expenditure per capita (current US$)',
      ['Luxembourg', 'Switzerland', 'Norway', 'United States'], [2000, 2017])
trend(data, 'Domestic general government health expenditure per capita (current US$)',
      ['Burundi', 'Malawi', 'Niger', 'Mozambique'], [2000, 2017])

# %%
scatter(data, ['Individuals using the Internet (% of population)',
               'GDP per capita (current US$)'], [2017, 2001])
