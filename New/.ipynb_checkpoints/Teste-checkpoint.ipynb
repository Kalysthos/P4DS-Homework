# %%
import pandas as pd 
from scatter import scatter
data = pd.read_csv("WBData.csv").set_index(["Series Name", "Country Name"])

# %%
scatter(data, [2017,2017], ['GDP per capita (current US$)', "Women's share of population ages 15+ living with HIV (%)"])
# Out:
# (0.5503212298085421, -8.329286974057974, 127, 'log(x) - y')

# %%
list(set([i[0] for i in data.index]))
# Out:
# ['Technical cooperation grants (BoP, current US$)',
#  'Commercial bank branches (per 100,000 adults)',
#  'Population ages 0-14 (% of total)',
#  'General government final consumption expenditure (constant 2010 US$)',
#  'Principal rescheduled, official (current US$)',
#  'Population ages 80 and above, female (% of female population)',
#  'Life expectancy at birth, total (years)',
#  'Domestic credit to private sector (% of GDP)',
#  'Average grant element on new external debt commitments (%)',
#  'Children out of school, primary',
#  'Pupil-teacher ratio, secondary',
#  'Imports of goods and services (constant 2010 US$)',
#  'Net official flows from UN agencies, UNFPA (current US$)',
#  'Access to electricity, rural (% of rural population)',
#  'Access to electricity (% of population)',
#  'Tariff rate, applied, weighted mean, primary products (%)',
#  'Debt forgiveness or reduction (current US$)',
#  'Import unit value index (2000 = 100)',
# ...
