# %%
import pandas as pd 
from scatter import scatter
import matplotlib.pyplot as plt
from plots import trend, lmh, trend_years
data = pd.read_csv("WBData.csv").set_index(["Series Name", "Country Name"])

# %%
scatter(data, [2017,2017], ['GDP per capita (current US$)', "Women's share of population ages 15+ living with HIV (%)"], True)

# %%
index = 'GDP per capita (current US$)'
country = ['Afghanistan', 'Brazil']
years = [2000, 2017]
a = data.loc[(index, country), [str(i) for i in range(years[0], years[1] + 1)]]  #[[str(i) for i in range(years[0], years[1] + 1)]]

# %%
trend(data, index, country, years)

# %%
lmh(data,  'Economic freedom', 2017, 3)

# %%
country = 'World'
indexes = ['Economic freedom', 'GDP per capita (current US$)']
trend_years(data, indexes, country, years)

# %%
country = 'World'
indexes = 'Economic freedom'
trend_years(data, indexes, country, years)
