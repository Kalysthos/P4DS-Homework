# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm

# %%
heritage = pd.read_excel('index2017_data.xls', sheet_name='Sheet1')[["Country","2017 Score"]]
gdp = pd.read_excel("GDP_per_capita.xls", sheet_name='Data', header=3)[["Country Name", "2017"]]
heritage.join(gdp)
# Out:
#                     Country  2017 Score  \
# 0               Afghanistan   48.885716
# 1                   Albania   64.353003
# 2                   Algeria   46.528581
# 3                    Angola   48.515521
# 4                 Argentina   50.409088
# 5                   Armenia   70.306017
# 6                 Australia   81.015797
# 7                   Austria   72.265759
# 8                Azerbaijan   63.599004
# 9                   Bahamas   61.081741
# 10                  Bahrain   68.472391
# 11               Bangladesh   54.981640
# 12                 Barbados   54.501504
# 13                  Belarus   58.588849
# 14                  Belgium   67.846954
# 15                   Belize   58.629195
# 16                    Benin   59.237728
# 17                   Bhutan   58.445013
# 18                  Bolivia   47.696458
# 19   Bosnia and Herzegovina   60.221983
# 20                 Botswana   70.109960
# 21                   Brazil   52.853198
# 22                 Bulgaria   67.855456
# 23             Burkina Faso   59.610196
# 24                    Burma   52.483818
# 25                  Burundi   53.189931
# 26                 Cambodia   59.518220
# 27                 Cameroon   51.811193
# 28                   Canada   78.507499
# 29               Cabo Verde   56.949831
# ..                      ...         ...
# 156                  Sweden   74.913207
# 157             Switzerland   81.452148
# 158                   Syria         NaN
# 159                 Taiwan    76.506760
# 160              Tajikistan   58.167324
# 161                Tanzania   58.584720
# 162                Thailand   66.220285
# 163             Timor-Leste   46.266101
# 164                    Togo   53.238028
# 165                   Tonga   63.010861
# 166     Trinidad and Tobago   61.228271
# 167                 Tunisia   55.713272
# 168                  Turkey   65.230960
# 169            Turkmenistan   47.365115
# 170                  Uganda   60.912963
# 171                 Ukraine   48.091766
# 172    United Arab Emirates   76.894497
# 173          United Kingdom   76.431714
# 174           United States   75.136726
# 175                 Uruguay   69.670343
# 176              Uzbekistan   52.264522
# 177                 Vanuatu   67.392048
# 178               Venezuela   26.961476
# 179                 Vietnam   52.437551
# 180                   Yemen         NaN
# 181                  Zambia   55.799426
# 182                Zimbabwe   44.049860
# 183                 Somalia         NaN
# 184                  Kosovo   67.856706
# 185       Brunei Darussalam   69.771510
#
#                                           Country Name          2017
# 0                                                Aruba           NaN
# 1                                          Afghanistan    585.850064
# 2                                               Angola   4170.312280
# 3                                              Albania   4537.862492
# 4                                              Andorra  39146.548836
# 5                                           Arab World   6251.141575
# 6                                 United Arab Emirates  40698.849336
# 7                                            Argentina  14401.974855
# 8                                              Armenia   3936.798320
# 9                                       American Samoa           NaN
# 10                                 Antigua and Barbuda  15021.738183
# 11                                           Australia  53799.938090
# 12                                             Austria  47290.911650
# 13                                          Azerbaijan   4131.618310
# 14                                             Burundi    320.086870
# 15                                             Belgium  43323.807336
# 16                                               Benin    829.797231
# 17                                        Burkina Faso    670.705913
# 18                                          Bangladesh   1516.513423
# 19                                            Bulgaria   8031.598442
# 20                                             Bahrain  23655.035602
# 21                                        Bahamas, The  30762.012439
# 22                              Bosnia and Herzegovina   5180.636301
# 23                                             Belarus   5726.029673
# 24                                              Belize   4905.506284
# 25                                             Bermuda           NaN
# 26                                             Bolivia   3393.955818
# 27                                              Brazil   9821.407686
# 28                                            Barbados  16788.683920
# 29                                   Brunei Darussalam  28290.585196
# ..                                                 ...           ...
# 156                                               Mali    824.516226
# 157                                              Malta  26945.983882
# 158                                            Myanmar   1298.881989
# 159  Middle East & North Africa (excluding high inc...   3768.731836
# 160                                         Montenegro   7669.571906
# 161                                           Mongolia   3735.164302
# 162                           Northern Mariana Islands           NaN
# 163                                         Mozambique    415.717717
# 164                                         Mauritania   1136.763975
# 165                                          Mauritius  10547.216835
# 166                                             Malawi    338.483642
# 167                                           Malaysia   9944.904300
# 168                                      North America  58070.066137
# 169                                            Namibia   5227.180010
# 170                                      New Caledonia           NaN
# 171                                              Niger    378.060308
# 172                                            Nigeria   1968.557681
# 173                                          Nicaragua   2221.806445
# 174                                        Netherlands  48223.155494
# 175                                             Norway  75504.566255
# 176                                              Nepal    835.079847
# 177                                              Nauru   8343.827999
# 178                                        New Zealand  42940.578288
# 179                                       OECD members  38148.769669
# 180                                               Oman  15668.366627
# 181                                 Other small states  13134.424102
# 182                                           Pakistan   1547.853414
# 183                                             Panama  15087.681633
# 184                                               Peru   6571.928645
# 185                                        Philippines   2988.952703
#
# [186 rows x 4 columns]

# %%
a,b,lista = list(heritage["Country"]), list(gdp["Country Name"]), []
for i in a:
    var = 0
    for k in i.split():
        if var == 1:
            break
        if k not in ("of","the", "and ", "Korea"):
            for j in b:
                if k in j or (i,j) in [('Burma', 'Myanmar')] or \
                (i,j) in [('Macau', 'Macao SAR, China')] or \
                (i,j) in [('Swaziland', 'Eswatini' )] or \
                (i,j) in [('Taiwan ', 'East Asia & Pacific (excluding high income)' )]: 
                    lista.append(j)
                    b.remove(j)
                    var = 1
                    break
lib, pib = pd.DataFrame(heritage["2017 Score"] ), pd.DataFrame(gdp["2017"] )
lib.index,pib.index = lista, gdp["Country Name"]
lib = lib.reindex(gdp["Country Name"])
comp = pib.join(lib).dropna()
comp.columns = ["Index of Economic Freedom", "GDP per capita"]
comp["GDP per capita"][comp["GDP per capita"]<20]
# Out:
# Country Name
# Korea, Rep.    4.916667
# Name: GDP per capita, dtype: float64

# %%
plt.scatter( comp["GDP per capita"] ,comp["Index of Economic Freedom"])
plt.show()

# %%
var, comp.columns = 0, ["y","x"]
for i in np.arange(0.1,5,0.1):
    reg = sm.ols(formula='y~pow(x,{})'.format(i), data=comp).fit()
    if reg.rsquared > var:
        var = reg.rsquared
        k = i
reg = sm.ols(formula='y~pow(x,{})'.format(k), data=comp).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.461
# Model:                            OLS   Adj. R-squared:                  0.458
# Method:                 Least Squares   F-statistic:                     147.4
# Date:                Thu, 27 Sep 2018   Prob (F-statistic):           6.77e-25
# Time:                        18:19:51   Log-Likelihood:                -1909.6
# No. Observations:                 174   AIC:                             3823.
# Df Residuals:                     172   BIC:                             3829.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                  -4514.4835   1855.748     -2.433      0.016   -8177.456    -851.511
# pow(x, 4.3999999999999995)     0.0002   1.73e-05     12.141      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                       65.444   Durbin-Watson:                   2.212
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              212.562
# Skew:                           1.493   Prob(JB):                     6.96e-47
# Kurtosis:                       7.516   Cond. No.                     1.85e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.85e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
plt.scatter(y=comp['y'], x=comp['x'], color='blue', s=50, alpha=.5)
X_plot = sp.linspace(min(comp['x']), max(comp['x']), len(comp['x']))
plt.plot(X_plot, (X_plot**k)*reg.params[1] + reg.params[0], color='r')
plt.title('Linha de tendencia')
plt.xlabel("Index of Economic Freedom")
plt.ylabel("GDP per capita")
plt.show()
