# %%
from analyze import analise
import indic 
ind = indic.indices.split()

# %%
lista = []
for i in ind[5:-1]:
    a = analise(2017, i.replace("_", " ").replace(".xls",""), True, "analise")
    lista += [a]
    print("{:0.10f}".format(a[0]), "   ", i.replace("_", " ").replace(".xls",""))
# Out:
# 0.5975972079     Agriculture forestry and fishing value added
# 0.4632164755     Urban population
# 0.1429068795     Foreign direct investment net inflows
# 0.0023246629     Industry (including construction) value added
# 0.0110904513     GDP per capita growth
# 0.0538921985     Government expenditure on education total
# 0.0470488106     Gross savings
# 0.0687084873     Population growth
# 0.1537539159     Time required to start a business
# 0.0353313139     Total tax rate
# 0.0220789481     Unemployment total
# 0.4147556011     Ease of doing business index
# 0.0905385876     Expense

# %%
import matplotlib.pyplot as plt
labels = ind[5:-1]
sizes = [i[0] for i in lista]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal') 
plt.show()
