# %%
from analyze import analise

# %%
analise(2017,"Urban population",True,"plot")
# Out:
# Intercept       1383.744103
# pow(x, 3.58)       0.003425
# dtype: float64
# r**2: 0.46321647552043854
# Country: 233

# %%
analise(2017, 'Ease of doing business index', True, "plot")
